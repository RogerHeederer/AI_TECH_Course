# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerHeederer/AI_TECH_Course/blob/master/1%EC%A3%BC_1%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Naver AI TECH - Ustage 2일차 _ 2021.01.19

# %% [markdown]
# text-processing1,2
#
# basic-math
#
# 총 3가지 파이썬 구현 과제 수행
#
# 과제를 하면서 추가적으로 알게된 사항만을 정리

# %%
string = "  H  e  L    l   O   !"

string.lower().split() # 공백을 다 빼고 리스트로 담아줌
# Out:
# ['h', 'e', 'l', 'l', 'o', '!']

# %%
string2 = "__EXAMPLE__NAME__"

string2 = string2.replace('E', '!') #replace는 대입을 시켜야 원본이 바뀌며 + 'E'와 일치되는 걸 전부 찾아 변환시킨다.
string2
# Out:
# '__!XAMPL!__NAM!__'

# %%
string2 = "__EXAMPLE__NAME__"

string2 = string2.replace('E', '!', 1) #맨 첫 자리 E만 바꾸고 싶으면, 1번만 수행한다는 옵션을 주면 된다.
string2
# Out:
# '__!XAMPLE__NAME__'
