# %% [markdown]
# #2021_02_02 학습일지
#
# Variance : 인풋을 모델에 넣었을 때, 출력 결과가 얼마나 일관되게 나오는지
#
# Low variance-> 출력이 일관됨
# High variance -> 출력이 다양하게 나옴
#
# Bias : 타겟하고자 하는 값과 가까운지, 멀어지는지를 따진다
#
# low bias : 모델의 출력물들의 평균이 타겟하고자 하는 값과 가깝다
# high bias : 모델의 출력물들의 평균이 타겟하고자 하는 값과 멀다
#
# 근본적으로 학습 데이터에 노이즈가 껴있을 경우에는 bias와 variance는 트레이드오프 관계이다.
